# %% [markdown]
# # Instructions for Using this Jupyter Notebook
# * Instructions for using this template are in the README.md in the YeatsPythonTutorial
# * Have a 'Terminal' open below the notebook - this is how you run commands (excluding cells in the notebook). Terminal > New in Menu Bar.
# * Make sure pip is installed.
# * Make sure the requirements are installed
# ```
# python3 -m pip install -r requirements.txt
# ```
# * Make a copy of this within the repository (same folder) and save as your name
# * Configure VS Code so you can create or edit files with the 'code' command: In the Command Palette (CMD+SHIFT+P), type Shell Command: Install 'code' command in PATH and select it.

# %% [markdown]
# # ADD TO README
#
#
#
# 2. Clone thge Repository with the Tutorial with this command (depends on having SSH key setup)
# ```
# git clone git@github.com:jessicayeats/YeatsPythonTutorial.git
# ```
# 2. Within VS Code, Open terminal
# * Check which version of Python you're running
#
# ```
# python3 --version
# ```
# * Install pip
# * Add an example .csv in the directory
# * Add 'add code extention'
# * Show an example of opening a file with 'code xxx'

# %% [markdown]
# # Imports

# %%
# autoreload tells the jupyter notebook to reload imported functions
# %load_ext autoreload
# %autoreload

# Import standard libraries
import pandas as pd # Primary library for data analysis in  python
import numpy as np  # Supports the pandas library, math
import os # For navigating around your computer
import openai # Chat GPT API / Integration
import requests # For pinging websites / REST API Calls
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 10
#       8 import os # For navigating around your computer
#       9 import openai # Chat GPT API / Integration
# ---> 10 import requests # For pinging websites
#
# ModuleNotFoundError: No module named 'requests'

# %%
#
